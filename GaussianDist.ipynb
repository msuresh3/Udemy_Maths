# %% [markdown]
# <a href="https://colab.research.google.com/github/msuresh3/Udemy_Maths/blob/main/GaussianDist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Define mean and standard deviation
mu = 0  # Mean
sigma = 1  # Standard deviation

# Create values for the x-axis
x = np.linspace(mu - 4*sigma, mu + 4*sigma, 200)

# Calculate the PDF for the normal distribution
y = norm.pdf(x, mu, sigma)

# %%
# Calculate probabilities
print(f"P(X <= 0): {norm.cdf(0, mu, sigma):.4f}") # probability of X <= 0
print(f"P(X <= 1): {norm.cdf(1, mu, sigma):.4f}") # probability of X <= 1
print(f"P(X >= 1): {1-norm.cdf(1, mu, sigma):.4f}") # probability of X >= 1
print(f"P(X >= -1 and X <=1) : {norm.cdf(1, mu, sigma)-norm.cdf(-1, mu, sigma):.4f}") # probability of -1 <= X <= 1
print(f"P(X >= -2 and X <=2) : {norm.cdf(2, mu, sigma)-norm.cdf(-2, mu, sigma):.4f}") # probability of -2 <= X <= 2
print(f"P(X >= -3 and X <=3) : {norm.cdf(3, mu, sigma)-norm.cdf(-3, mu, sigma):.4f}") # probability of -3 <= X <= 3

# Calculate z-scores
x_val = 1.5
z_score = (x_val - mu)/sigma
print(f"The z-score for x = {x_val} is: {z_score}")

# Find the value at the 95th percentile
percentile = norm.ppf(0.95, mu, sigma)
print(f"The value at 95th percentile: {percentile}")
# Out:
# P(X <= 0): 0.5000
# P(X <= 1): 0.8413
# P(X >= 1): 0.1587
# P(X >= -1 and X <=1) : 0.6827
# P(X >= -2 and X <=2) : 0.9545
# P(X >= -3 and X <=3) : 0.9973
# The z-score for x = 1.5 is: 1.5
# The value at 95th percentile: 1.6448536269514722

# %%
# Plot the normal distribution curve
plt.plot(x, y, label='Normal Distribution')
plt.title(f'Normal Distribution (μ={mu}, σ={sigma})')
plt.xlabel('x')
plt.ylabel('Probability Density')
# Out:
# Text(0, 0.5, 'Probability Density')

# %%
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Normal Distribution (μ=0, σ=1)', color='blue')
plt.fill_between(x, y, where=(x >= -1) & (x <= 1), color='lightblue', alpha=0.5, label='1σ (68%)')
plt.fill_between(x, y, where=(x >= -2) & (x <= 2), color='lightgreen', alpha=0.5, label='2σ (95%)')
plt.fill_between(x, y, where=(x >= -3) & (x <= 3), color='lightcoral', alpha=0.5, label='3σ (99.7%)')

plt.xlabel('x')
plt.ylabel('Probability Density')
plt.title('Normal Distribution with Confidence Intervals')

plt.legend()
plt.grid(True)
plt.show()
