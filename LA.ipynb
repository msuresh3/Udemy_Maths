# %% [markdown]
# <a href="https://colab.research.google.com/github/msuresh3/Udemy_Maths/blob/main/LA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Linear Algebra**
# **Matrix Addition**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
arr1 = np.array([-4,3])
arr2 = np.array([5,3])

#ax.quiver(0, 0, arr1[0], arr1[1], color='red')
#ax.quiver(0, 0, arr2[0], arr2[1], color='blue')

# %%
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
arr3 = arr1 + arr2
# Out:
# array([1, 6])

# %%
#plt.quiver(0, 0, -4, 3, scale_units='xy', angles='xy', scale=1,color='red')
#plt.quiver(0, 0, 5, 3, scale_units='xy', angles='xy', scale=1,color='blue')
#plt.quiver(0, 0, 1, 6, scale_units='xy', angles='xy', scale=1,color='black') #Output of array addition

plt.quiver(*arr1, color='red')
plt.quiver(*arr2, color='blue')
plt.quiver(*arr3, color='black')

plt.xlim(-6, 6)
plt.ylim(-6, 6)

plt.xlabel('x')
plt.ylabel('y')

plt.grid()
plt.show()
